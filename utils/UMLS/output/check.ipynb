# %%
import pandas as pd

df = pd.read_csv("./umls_entities_bioASQ.csv")
print(df.head())
# Out:
#         CUI SemanticGroups                                      SemanticTypes  \
# 0  C0000005           CHEM  T116:Amino Acid, Peptide, or Protein||T121:Pha...
# 1  C0000039           CHEM  T109:Organic Chemical||T121:Pharmacologic Subs...
# 2  C0000052           CHEM  T116:Amino Acid, Peptide, or Protein||T126:Enzyme
# 3  C0000074           CHEM                              T109:Organic Chemical
# 4  C0000084           CHEM  T116:Amino Acid, Peptide, or Protein||T123:Bio...
#
#                                           Definition  \
# 0                                                NaN
# 1  Synthetic phospholipid used in liposomes and l...
# 2  In glycogen or amylopectin synthesis, the enzy...
# 3                                                NaN
# 4  Found in various tissues, particularly in four...
#
#                                                Terms
# 0         (131)i-maa||(131)i-macroaggregated albumin
# 1  1,2 dihexadecyl sn glycerophosphocholine||1,2 ...
# ...

# %%
df.shape
# Out:
# (1829940, 5)

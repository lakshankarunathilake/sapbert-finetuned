# %%
import pandas as pd

df = pd.read_csv("./umls_entities_bioASQ.csv")
print(df.head())
# Out:
#         CUI SemanticGroups                                      SemanticTypes  \
# 0  C0000005           CHEM  T116:Amino Acid, Peptide, or Protein||T121:Pha...
# 1  C0000039           CHEM  T109:Organic Chemical||T121:Pharmacologic Subs...
# 2  C0000052           CHEM  T116:Amino Acid, Peptide, or Protein||T126:Enzyme
# 3  C0000074           CHEM                              T109:Organic Chemical
# 4  C0000084           CHEM  T116:Amino Acid, Peptide, or Protein||T123:Bio...
#
#                                           Definition  \
# 0                                                NaN
# 1  Synthetic phospholipid used in liposomes and l...
# 2  In glycogen or amylopectin synthesis, the enzy...
# 3                                                NaN
# 4  Found in various tissues, particularly in four...
#
#                                                Terms
# 0         (131)i-maa||(131)i-macroaggregated albumin
# 1  1,2 dihexadecyl sn glycerophosphocholine||1,2 ...
# ...

# %%
df.shape
# Out:
# (2230631, 5)

# %%
df[df["CUI"] == "C0041618"]
# Out:
#             CUI SemanticGroups              SemanticTypes  \
# 16506  C0041618        LABPROC  T060:Diagnostic Procedure
#
#                                               Definition  \
# 16506  The visualization of deep structures of the bo...
#
#                                                    Terms
# 16506  2-dimensional grayscale ultrasound imaging||2-...

# %%
2-dimensional grayscale ultrasound imaging||2-dimensional ultrasound imaging||2d-us||diagnosis (us)||diagnosis, ultrasound||diagnostic echography||diagnostic sonar||diagnostic ultrasonography||diagnostic ultrasonography, nos||diagnostic ultrasound||diagnostic ultrasound procedure||diagnostic ultrasounds||diagnostics ultrasound||echographies||echography||echography, nos||general ultrasound procedures||imaging, ultrasonic||imaging, ultrasonographic||imaging, ultrasound||imagings, ultrasonographic||imagings, ultrasound||medical sonography||procedure ultrasound||scan ultrasound||scans ultrasound||sonogram||sonograms||sonography, medical||technique ultrasound||testing ultrasound||tests ultrasound||ultrasonic imaging||ultrasonographic imaging||ultrasonographic imagings||ultrasonography||ultrasonography (procedure)||ultrasonography, nos||ultrasound diagnostic||ultrasound diagnostic procedure||ultrasound imaging||ultrasound imaging - action||ultrasound imaging - action (qualifier value)||ultrasound imaging/scanning||ultrasound procedure||ultrasound procedure, nos||ultrasound procedures||ultrasound scan||ultrasound scan nos||ultrasound scan, nos||ultrasound studies||ultrasound studies (procedure)||ultrasound technique||ultrasound techniques||ultrasound test||ultrasound, diagnostic||ultrasound, medical||ultrasounds||ultrasounds, diagnostic||unlisted diagnostic ultrasound examination or procedure, explain by report||unlisted ultrasound procedure (eg, diagnostic, interventional)||unlisted us procedure||us - ultrasound||uss - ultrasound scan||diagnostic ultrasound procedures||e0005878||e0701772||e0701773||e0701774||e0761031||echotomography||gen.us||general ultrasound||imaging ultrasound||sonography||sound measurement||ultrasonogram||ultrasound||ultrasound scanning||us
